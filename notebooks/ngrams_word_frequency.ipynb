# %% [markdown]
# ### Word Frequency and N-Grams

# %% [markdown]
# #### Import modules

# %%
import sys, os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from util import Util

# %%
cleaned_dir = "../data/cleaned"
final_dir = "../data/final"
file_name = "TIKVAH-ETHIOPIA"
util = Util()

# %%
df = pd.read_csv(f"{cleaned_dir}/{file_name}.csv", index_col='id')
df.head()
# Out:
#                                                     text                 date  \
# id
# 83647  ለጥያቄና መልስ ውድድራችን ዝግጁ ነዎት? 3ኛ ዙር የጥያቄና መልስ ውድድር...  2023-12-19T11:08:29
# 83650  ስትሮክ ፦ ስትሮክ በተለያየ ምከንያት ኦክስጅንን ለአእምሮ ሚያደርሰው የደ...  2023-12-19T11:08:40
# 83653  ዛሬ የሕዝብ ተወካዮች ምክር ቤት ባካሄደው መደበኛ ስብሰባው ወ/ሮ ምእላተ...  2023-12-19T11:09:18
# 83655  ኬኖ ለሚባለው የቁጥር ግመታ ጨዋታ ፈቃድ አልሰጠሁም የብሄራዊ ሎተሪ አስተ...  2023-12-19T11:25:42
# 83657  ታህሳስ 7 ቀን 2016 ኣ/ም ምሽት አዲስ አበባ ቦሌ ኤድና ሞል አካባቢ ...  2023-12-19T14:11:36
#
#                                                 hashtags emojis  \
# id
# 83647  ['#አቢሲንያ_ባንክ', '#telegram', '#giveaway', '#con...    NaN
# 83650                                       ['#እንድታውቁት']      ☑
# 83653                                          ['#NEBE']    NaN
# 83655                                                 []    NaN
# 83657          ['#AddisAbaba', '#አባተ_አበበ', '#መሳሪያ_በታጠቀ']    NaN
#
#                                  symbols                    links
# id
# 83647                                  ፤  ['https://t.me/BoAEth']
# 83650                         -።።።-።-።-።                       []
# 83653  ።።-።።-።-።።-።-።-።-።-።።።።።።።-።-።-።።                       []
# 83655                     "''"-""፤""።""።                       []
# 83657                           ።።።።።።፤።                       []

# %% [markdown]
# #### Word Frequency

# %%
# function to convert token to list and unpack
from functools import reduce
import operator


def term_freq(x):
    # Tokenize each text into words
    word_lists = [str(text).split() for text in x.tolist()]
    
    # Flatten the list of lists
    words = reduce(operator.add, word_lists)
    
    return words

# %%
# function to count the term/word and create a dataframe for frequencies
from collections import Counter

def counting(x, y):
  counter = Counter(x)
  most_occurrences = counter.most_common()
  count_df = pd.DataFrame(most_occurrences, columns = ['Word', 'Count'])
  return count_df

# %%
df_frequency = counting(term_freq(df['text']), 2)
df_frequency.head()
# Out:
#     Word  Count
# 0     ነው    240
# 1     እና    220
# 2     ላይ    164
# 3  ኢትዮጵያ    126
# 4     ጋር     89

# %% [markdown]
# #### Save word frequency

# %%
df_frequency.to_csv(f"{final_dir}/{file_name}_frequency.csv")

# %% [markdown]
# #### n-grams

# %%
import re


def list_and_tokenize(data):
    return str(data).split()

# %%
# function to prepare n-grams
import collections

def count_n_grams(lines, min_length=2, max_length=4):
    lengths = range(min_length, max_length + 1)
    n_grams = {length: collections.Counter() for length in lengths}
    queue = collections.deque(maxlen=max_length)

    # Helper function to add n-grams at start of current queue to dict
    def add_queue():
        current = tuple(queue)
        for length in lengths:
            if len(current) >= length:
                n_grams[length][current[:length]] += 1

    # Loop through all lines and words and add n-grams to dict
    for line in lines:
        for word in list_and_tokenize(line):
            # if len(word) > 3:
            queue.append(word)
            if len(queue) >= max_length:
                add_queue()

    # Make sure we get the n-grams at the tail end of the queue
    while len(queue) > min_length:
        queue.popleft()
        add_queue()

    return n_grams

# %%
bigram_to_df = pd.DataFrame({'2-grams': [], '2-grams freq': []})
trigram_to_df = pd.DataFrame({'3-grams': [], '3-grams freq': []})
quadgram_to_df = pd.DataFrame({'4-grams': [], '4-grams freq': []})

bigram = {'2-grams': [], '2-grams freq': []}
trigram = {'3-grams': [], '3-grams freq': []}
quadgram = {'4-grams': [], '4-grams freq': []}
    
def print_most_freq_ng(n_grams, num=30):
    global bigram_to_df, trigram_to_df, quadgram_to_df
    for n in sorted(n_grams):
        for gram, count in n_grams[n].most_common(num):
            if n == 2:
                bigram['2-grams'].append(gram)
                bigram['2-grams freq'].append(count)
            elif n == 3:
                trigram['3-grams'].append(gram)
                trigram['3-grams freq'].append(count)
            else:
                quadgram['4-grams'].append(gram)
                quadgram['4-grams freq'].append(count)
                
    bigram_to_df = pd.DataFrame({'2-grams': bigram['2-grams'], '2-grams freq': bigram['2-grams freq']})
    trigram_to_df = pd.DataFrame({'3-grams': trigram['3-grams'], '3-grams freq': trigram['3-grams freq']})
    quadgram_to_df = pd.DataFrame({'4-grams': quadgram['4-grams'], '4-grams freq': quadgram['4-grams freq']})

# %%
print_most_freq_ng(count_n_grams(df['text']))
n_gram_df = pd.concat([bigram_to_df, trigram_to_df, quadgram_to_df], axis=1)

n_gram_df
# Out:
#                   2-grams  2-grams freq                     3-grams  \
# 0             (የአዲስ, አበባ)            40            (የአዲስ, አበባ, ከተማ)
# 1           (ቲክቫህ, ኢትዮጵያ)            37          (ኢትዮጵያ, ቤተሰብ, አባል)
# 2              (አበባ, ከተማ)            30          (አበባ, ከተማ, አስተዳደር)
# 3          (ለቲክቫህ, ኢትዮጵያ)            25                 (ምን, አሉ, ?)
# 4   (ነው, @tikvahethiopia)            23        (የቲክቫህ, ኢትዮጵያ, ቤተሰብ)
# 5             (ቤተሰብ, አባል)            20             (ቤተሰብ, አባል, ነው)
# 6           (ከተማ, አስተዳደር)            19  (አባል, ነው, @tikvahethiopia)
# 7              (ቀን, 2016)            18          (ቴክኖ, ሞባይል, ኢትዮጵያ)
# 8           (ኢትዮጵያ, ቤተሰብ)            18        (የመቐለ, የቲክቫህ, ኢትዮጵያ)
# 9             (በአዲስ, አበባ)            16             (ሰርቪስ, እና, የሰው)
# 10                 (፦, *)            14       (የትግራይ, ጊዚያዊ, አስተዳደር)
# 11            (ከአዲስ, አበባ)            13             (ቀን, 2016, ኣ/ም)
# 12         (የቲክቫህ, ኢትዮጵያ)            13             (ቀን, 2016, ኣ.ም)
# 13               (ምን, አሉ)            13         (ቲክቫህ, ኢትዮጵያ, ቤተሰብ)
# 14                (አሉ, ?)            13              (እና, የሰው, ሀብት)
# 15           (ትምህርት, ቤቶች)            13             (የሰው, ሀብት, ልማት)
# 16            (ጋር, በተያያዘ)            12         (የአ/አ, ቲክቫህ, ኢትዮጵያ)
# 17              (አሁን, ላይ)            12            (ቀን, 2016, ኣ.ም.)
# 18          (አበባ, ዩኒቨርሲቲ)            11         (ከተማ, አስተዳደር, ፐብሊክ)
# 19              (አባል, ነው)            11        (አስተዳደር, ፐብሊክ, ሰርቪስ)
# 20                 (., .)            11            (ፐብሊክ, ሰርቪስ, እና)
# 21             (አዲስ, አበባ)            10              (ሀብት, ልማት, ቢሮ)
# 22             (ከተማ, ፖሊስ)            10            (ከአዲስ, አበባ, ከተማ)
# 23            (2016, ኣ.ም)            10                   (., ., .)
# 24            (የፀጥታ, ችግር)            10          (የቴክኒክና, ባህሪ, ብቃት)
# 25            (ትምህርት, ቤት)             9        (የብሄራዊ, ሎተሪ, አስተዳደር)
# 26            (በአማራ, ክልል)             9            (የአዲስ, አበባ, ፖሊስ)
# 27                (ነው, °)             9        (ለቲክቫህ, ኢትዮጵያ, በሰጡት)
# 28              (ነገር, ግን)             9             (አገር, አቀፍ, ፈተና)
# 29             (ነው, ብለዋል)             8          (የላከው, የአ/አ, ቲክቫህ)
#
#     3-grams freq                           4-grams  4-grams freq
# 0             21          (የአዲስ, አበባ, ከተማ, አስተዳደር)            12
# 1             16         (የቲክቫህ, ኢትዮጵያ, ቤተሰብ, አባል)            10
# 2             14  (ቤተሰብ, አባል, ነው, @tikvahethiopia)            10
# 3             13            (ኢትዮጵያ, ቤተሰብ, አባል, ነው)             9
# 4             12        (የመቐለ, የቲክቫህ, ኢትዮጵያ, ቤተሰብ)             6
# 5             11          (ቲክቫህ, ኢትዮጵያ, ቤተሰብ, አባል)             6
# 6             10              (ሰርቪስ, እና, የሰው, ሀብት)             6
# 7              7               (እና, የሰው, ሀብት, ልማት)             6
# 8              7         (የአ/አ, ቲክቫህ, ኢትዮጵያ, ቤተሰብ)             5
# 9              7          (አበባ, ከተማ, አስተዳደር, ፐብሊክ)             5
# 10             7         (ከተማ, አስተዳደር, ፐብሊክ, ሰርቪስ)             5
# 11             6          (አስተዳደር, ፐብሊክ, ሰርቪስ, እና)             5
# 12             6             (ፐብሊክ, ሰርቪስ, እና, የሰው)             5
# 13             6               (የሰው, ሀብት, ልማት, ቢሮ)             5
# 14             6         (የላከው, የአ/አ, ቲክቫህ, ኢትዮጵያ)             4
# 15             6           (ቅድመ, አንደኛ, ደረጃ, ትምህርት)             4
# 16             5            (አንደኛ, ደረጃ, ትምህርት, ቤት)             4
# 17             5                (ዞን, ጤና, መምሪያ, ቢሮ)             4
# 18             5            (ከ2, ሚሊዮን, በላይ, ተማሪዎች)             4
# 19             5      (የትግራይ, ጊዚያዊ, አስተዳደር, ከፌደራል)             4
# 20             5      (ጊዚያዊ, አስተዳደር, ከፌደራል, መንግስት)             4
# 21             5              (የኣይን, ብሌን, ቀዶ, ጥገና)             4
# 22             5             (እየሰራ, ነው, ግልፅ, ማድረግ)             3
# 23             5            (ነው, ግልፅ, ማድረግ, በሚገባን)             3
# 24             5           (ግልፅ, ማድረግ, በሚገባን, ሰኣት)             3
# 25             4            (ማድረግ, በሚገባን, ሰኣት, ላይ)             3
# 26             4             (በሚገባን, ሰኣት, ላይ, ግልፅ)             3
# 27             4           (ሰኣት, ላይ, ግልፅ, እናደርጋለን)             3
# 28             4             (የ12ኛ, ክፍል, አገር, አቀፍ)             3
# 29             4              (ክፍል, አገር, አቀፍ, ፈተና)             3

# %% [markdown]
# #### Save n-grams

# %%
n_gram_df.to_csv(f"{final_dir}/{file_name}_n_gram.csv")
